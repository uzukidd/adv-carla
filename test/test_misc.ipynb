# %%
import pickle as pkl

trainval_path = "/home/ksas/Public/datasets/KITTI/kitti_infos_trainval.pkl"
train_path = "/home/ksas/Public/datasets/KITTI/kitti_infos_train.pkl"

with open(train_path, "rb") as input:
    train_pkl = pkl.load(input)
    
with open(trainval_path, "rb") as input:
    trainval_pkl = pkl.load(input)

# %%
print(trainval_pkl.__len__())
print(train_pkl.__len__())
# Out:
# 7481
# 3712

# %%
import numpy as np

mat_1 = np.random.rand(7, 4)
mat_2 = np.random.rand(4, 5)

mat_res = np.matmul(mat_1, mat_2)

print(mat_res.shape)
# Out:
# (7, 5)

# %%
import torch

mat_1 = torch.rand((3, 2, 10, 4, 5))
mat_2 =torch.rand((3, 2, 10, 5, 4))

mat_res = torch.matmul(mat_1, mat_2)

print(mat_res.size())
# Out:
# torch.Size([3, 2, 10, 4, 4])
